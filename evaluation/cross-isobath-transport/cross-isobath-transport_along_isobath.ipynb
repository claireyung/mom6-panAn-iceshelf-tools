# %% [markdown]
# ## Cross isobath transport, plot along isobath, analysis notebook
#
# For `8km_jra_ryf_obc_Charrassin` experiment (MOM6-CICE6 panan 1/12th degree ~ 4km with no ice shelves)
#
# **Note** Several non-standard uses of `esm_datastore`:
#
# - `esm_datastore` was generated with a different branch to main to pick up incorrectly named files (see https://github.com/ACCESS-NRI/access-nri-intake-catalog/issues/459, thanks to Charles Turner for fixing this for me)
# - Years 9 and 10 of this run used parallelised IO, and unfortunately the tiling resulted in NaNs along part of the y axis in these files. Therefore, we must use a preprocessing function that replaces these axes with that of an earlier time (month 0) (thanks to Jemma Jeffree for her help with this!)

# %%
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr
from dask.distributed import Client
import intake
import cmocean as cm

# %%
client = Client(threads_per_worker = 1)
client.amm.start()
memory_limit=0
client
# Out:
# <Client: 'tcp://127.0.0.1:43805' processes=28 threads=28, memory=128.00 GiB>
# 2025-09-19 11:27:42,108 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:33597 (pid=4141898) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:27:42,176 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:33597' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'original-open_dataset-vmo-bd43ccfc02dc75cddf859c6816f80768'} (stimulus_id='handle-worker-cleanup-1758245262.1758397')
# 2025-09-19 11:27:42,188 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:27:42,253 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:36507 (pid=4141866) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:27:42,261 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:36807 (pid=4141902) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:27:42,350 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:36507' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'original-open_dataset-umo-1242498bc2399767fc63f651ceebe53c', 'original-open_dataset-vmo-2922bc81e68a980ef6879e26d6f689ec'} (stimulus_id='handle-worker-cleanup-1758245262.3506799')
# 2025-09-19 11:27:42,387 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:36807' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'original-open_dataset-umo-ecd592b75cc01866922d3077d06ac5fa', 'original-open_dataset-vmo-df0382e2a6a1285aa59007f784123f20'} (stimulus_id='handle-worker-cleanup-1758245262.3871753')
# 2025-09-19 11:27:42,400 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:27:42,414 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:27:42,443 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:43707 (pid=4141818) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:27:42,504 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:43707' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'original-open_dataset-vmo-51b06a7b544edf7889cd4116f93e2624', 'original-open_dataset-umo-dbdfc47592edc6964d0a05c4941db14c'} (stimulus_id='handle-worker-cleanup-1758245262.5042846')
# 2025-09-19 11:27:42,516 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:27:42,519 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:43229 (pid=4141914) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:27:42,544 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:33291 (pid=4141822) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:27:42,610 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:43229' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'shuffle-taker-e65c235e74faa3d5529f3280874e8046', 'original-open_dataset-umo-f8a85cdf1e2d05a1e9220b86783d28b6', ('open_dataset-umo-concatenate-08ce81061ea57cd4ad239efda670c8ad', 114, 0, 0, 2), 'shuffle-taker-dfdfdea872dcd4b676f891eda6ba1456', 'shuffle-taker-af7f7e9eede5d5e56f0e782e8dcfaf84'} (stimulus_id='handle-worker-cleanup-1758245262.6099224')
# 2025-09-19 11:27:42,618 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:33291' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'original-open_dataset-umo-75026478607e3acb358bb97ba5879822', ('array-3cb0317acd6b8d45de1989e963b4dfdf', 0), ('open_dataset-umo-concatenate-08ce81061ea57cd4ad239efda670c8ad', 113, 0, 0, 2), 'shuffle-sorter-fed0db7ce4210f332fa1dedd9057a72c', 'shuffle-taker-6b55c9f78e4470b1be9bb1c9fec5f633'} (stimulus_id='handle-worker-cleanup-1758245262.6185808')
# 2025-09-19 11:27:42,627 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:27:42,631 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:27:42,913 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:34035 (pid=4141907) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:27:42,984 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:34035' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'shuffle-sorter-1aeb640420f945411aa21959d3c38cad', ('rechunk-merge-11dc4790778f88124baf0d4162e780ba', 0, 2), 'shuffle-taker-3da78b405e2e583edf85f9717fc72214', ('rechunk-merge-11dc4790778f88124baf0d4162e780ba', 0, 1), 'shuffle-taker-357592500159f29cf33a2c98c6bd7e82', ('rechunk-merge-11dc4790778f88124baf0d4162e780ba', 0, 0)} (stimulus_id='handle-worker-cleanup-1758245262.9842424')
# 2025-09-19 11:27:42,999 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:27:43,457 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:34931 (pid=4141893) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:27:43,535 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:34931' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'shuffle-taker-bec038514672a6514ec9d8cc0ba1af1f', ('rechunk-merge-74d0621e988a0e66af72c287551c4d2c', 0, 0), ('rechunk-merge-74d0621e988a0e66af72c287551c4d2c', 0, 1), 'original-open_dataset-umo-ec87de94d5a98bf06676c15771c96d77'} (stimulus_id='handle-worker-cleanup-1758245263.535273')
# 2025-09-19 11:27:43,548 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:27:43,699 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:39621 (pid=4141825) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:27:43,755 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:42995 (pid=4141870) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:27:43,761 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:39621' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'original-open_dataset-umo-de491a5a982aeae2e2b7b61a96b836de', 'original-open_dataset-vmo-976e839040eca3d5ed9218acfbd8c8c2'} (stimulus_id='handle-worker-cleanup-1758245263.7617083')
# 2025-09-19 11:27:43,775 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:27:43,830 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:42995' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'original-open_dataset-vmo-4210ad27a97f5de1351fa08ba7708f65', 'original-open_dataset-umo-9cb85f50adfa64ed1475641fed75f054'} (stimulus_id='handle-worker-cleanup-1758245263.8301198')
# 2025-09-19 11:27:43,888 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:27:43,908 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:45357 (pid=4141891) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:27:44,032 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:45357' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'original-open_dataset-umo-6221f1a659dbb227233c8f0082e0d466', 'original-open_dataset-vmo-09fda1362f67b86ec5f1eb70c5c8b664'} (stimulus_id='handle-worker-cleanup-1758245264.0321434')
# 2025-09-19 11:27:44,043 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:27:44,053 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:42915 (pid=4141853) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:27:44,097 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:46621 (pid=4141838) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:27:44,111 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:42915' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'original-open_dataset-umo-a75c6616a1575009bf5e9218a16f495b', 'original-open_dataset-vmo-007194d6c5c571b8699aaaa16f098799'} (stimulus_id='handle-worker-cleanup-1758245264.1112318')
# 2025-09-19 11:27:44,119 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:27:44,148 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:37519 (pid=4141843) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:27:44,153 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:41221 (pid=4141858) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:27:44,161 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:46621' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'original-open_dataset-vmo-fa8ef7c4f723fa2c3932bd6a35884cce', 'original-open_dataset-umo-84d8fe91f7554d349222932b5740c4d2'} (stimulus_id='handle-worker-cleanup-1758245264.1617131')
# 2025-09-19 11:27:44,171 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:27:44,215 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:37519' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'original-open_dataset-umo-e77762e4d2b1179f51b75e6995495261', 'original-open_dataset-vmo-841fe921c13737e7481533de23f4d372'} (stimulus_id='handle-worker-cleanup-1758245264.214916')
# 2025-09-19 11:27:44,224 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:27:44,231 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:41221' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'original-open_dataset-vmo-91c59c49441b404479fb1239d569da2f', 'shuffle-taker-ae20db758be2260df01fc28d134f7643'} (stimulus_id='handle-worker-cleanup-1758245264.231224')
# 2025-09-19 11:27:44,238 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:27:44,553 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:36033 (pid=4141863) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:27:44,614 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:36033' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'original-open_dataset-umo-f74af81093b3a01fa8bae1cf3c615fa4', 'original-open_dataset-vmo-131d595fe87e61df846d6acde8212f81'} (stimulus_id='handle-worker-cleanup-1758245264.6146395')
# 2025-09-19 11:27:44,622 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:27:44,796 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:42637 (pid=4141829) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:27:44,867 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:42637' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'original-open_dataset-vmo-e887e2d16bdf3d17550b252ab1520b2e', 'original-open_dataset-umo-d2461f0a2bc0dda68fd98845ddb0bccb'} (stimulus_id='handle-worker-cleanup-1758245264.8670907')
# 2025-09-19 11:27:44,872 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:27:46,913 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:35317 (pid=4141912) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:27:46,984 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:35317' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'original-open_dataset-umo-1cdd0eeb977ddbead85a16a2ff2ab95a', 'original-open_dataset-vmo-237d3fcab6a6c90c08715eed0041800c'} (stimulus_id='handle-worker-cleanup-1758245266.9839973')
# 2025-09-19 11:27:46,990 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:27:49,707 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:41415 (pid=4141851) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:27:49,768 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:41415' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'original-open_dataset-vmo-398687b5278d43a8c70e6bf9c60bf32f'} (stimulus_id='handle-worker-cleanup-1758245269.76815')
# 2025-09-19 11:27:49,791 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:27:49,797 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:42315 (pid=4141834) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:27:49,865 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:36483 (pid=4141878) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:27:49,870 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:42315' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'original-open_dataset-vmo-b46b9a8bff5b0ce460a07a29246a37cc'} (stimulus_id='handle-worker-cleanup-1758245269.8702567')
# 2025-09-19 11:27:49,885 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:27:49,932 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:36483' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'original-open_dataset-vmo-a6671ab5d56bc510b6c21779e817897f', ('array-9d457c38cd345eaee732529f27b1b397', 0)} (stimulus_id='handle-worker-cleanup-1758245269.9320343')
# 2025-09-19 11:27:49,942 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:27:51,542 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:37915 (pid=4141810) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:27:51,727 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:37915' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'original-open_dataset-vmo-df2e9ebd6ee1fca3468a507fd965cebe'} (stimulus_id='handle-worker-cleanup-1758245271.7272189')
# 2025-09-19 11:27:51,773 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:27:52,154 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:38593 (pid=4141873) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:27:52,227 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:38593' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'original-open_dataset-vmo-44e42b1eb51616d34521b6ba046e4a00'} (stimulus_id='handle-worker-cleanup-1758245272.227017')
# 2025-09-19 11:27:52,242 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:27:52,871 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:36533 (pid=4141889) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:27:52,956 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:36533' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'original-open_dataset-vmo-67cef4c4c753cbfa8c9d74364690201b'} (stimulus_id='handle-worker-cleanup-1758245272.9562762')
# 2025-09-19 11:27:52,980 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:27:54,157 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:33393 (pid=4141884) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:27:54,241 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:33393' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'original-open_dataset-vmo-d933efe6d46d8bc3f639c984d650e10f'} (stimulus_id='handle-worker-cleanup-1758245274.2409122')
# 2025-09-19 11:27:54,251 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:27:54,831 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:42779 (pid=4141846) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:27:54,907 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:42779' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'original-open_dataset-vmo-4d40288f0a3ac6e13f477a4e463b39a1'} (stimulus_id='handle-worker-cleanup-1758245274.907687')
# 2025-09-19 11:27:54,932 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:27:55,422 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:36505 (pid=4141916) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:27:55,505 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:36505' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'original-open_dataset-vmo-272c2176417c97c89198851248954ef5'} (stimulus_id='handle-worker-cleanup-1758245275.5048845')
# 2025-09-19 11:27:55,522 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:27:59,247 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:43211 (pid=4142357) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:27:59,273 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:43355 (pid=4142370) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:27:59,347 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:43355' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('mean_chunk-183fe4cd1df467827efcc315f5b5dc3a', 9, 0, 2), ('mean_chunk-183fe4cd1df467827efcc315f5b5dc3a', 4, 0, 2)} (stimulus_id='handle-worker-cleanup-1758245279.3476307')
# 2025-09-19 11:27:59,356 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:43211' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('open_dataset-umo-concatenate-08ce81061ea57cd4ad239efda670c8ad', 101, 0, 0, 2)} (stimulus_id='handle-worker-cleanup-1758245279.3562326')
# 2025-09-19 11:27:59,397 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:27:59,413 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:27:59,544 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:43357 (pid=4142377) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:27:59,618 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:27:59,726 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:40333 (pid=4142376) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:27:59,762 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:36375 (pid=4142419) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:27:59,794 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:40333' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('rechunk-merge-11dc4790778f88124baf0d4162e780ba', 0, 0), ('rechunk-merge-11dc4790778f88124baf0d4162e780ba', 0, 1), ('rechunk-merge-11dc4790778f88124baf0d4162e780ba', 0, 2), ('getitem-sum-sum-aggregate-mean_chunk-183fe4cd1df467827efcc315f5b5dc3a', 17, 0, 2)} (stimulus_id='handle-worker-cleanup-1758245279.7938402')
# 2025-09-19 11:27:59,809 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:27:59,828 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:00,200 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:38511 (pid=4142445) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:00,263 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:00,303 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:33753 (pid=4142470) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:00,309 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:32915 (pid=4142382) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:00,365 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:32915' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('mean_chunk-183fe4cd1df467827efcc315f5b5dc3a', 20, 0, 2), 'shuffle-taker-626337623fc64f402b35f5c79b66f2eb', ('mean_chunk-183fe4cd1df467827efcc315f5b5dc3a', 7, 0, 2), ('mean_chunk-183fe4cd1df467827efcc315f5b5dc3a', 3, 0, 2)} (stimulus_id='handle-worker-cleanup-1758245280.3653405')
# 2025-09-19 11:28:00,425 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:38821 (pid=4142366) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:00,478 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:00,509 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:00,517 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:38821' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('mean_chunk-183fe4cd1df467827efcc315f5b5dc3a', 11, 0, 2), 'original-open_dataset-umo-a75c6616a1575009bf5e9218a16f495b', ('mean_chunk-183fe4cd1df467827efcc315f5b5dc3a', 18, 0, 2)} (stimulus_id='handle-worker-cleanup-1758245280.5171611')
# 2025-09-19 11:28:00,545 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:00,564 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:45909 (pid=4142449) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:00,643 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:00,659 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:45925 (pid=4142474) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:00,711 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:45925' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'original-open_dataset-umo-1f0ac51b8519ef90758550b35f46ad06', 'original-open_dataset-umo-a531f9647a838fe7e917da6cd20e8920'} (stimulus_id='handle-worker-cleanup-1758245280.711274')
# 2025-09-19 11:28:00,715 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:41651 (pid=4142460) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:00,727 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:00,753 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:39095 (pid=4142492) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:00,778 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:41651' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'original-open_dataset-umo-5a02024ca79271e909c216e7f8f543c3', 'original-open_dataset-umo-52ba6e0e9f0e90730b8c4d04306b7b03'} (stimulus_id='handle-worker-cleanup-1758245280.7782028')
# 2025-09-19 11:28:00,799 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:00,809 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:00,853 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:35299 (pid=4142465) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:00,856 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:35939 (pid=4142478) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:00,897 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:00,932 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:01,099 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:44421 (pid=4142511) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:01,136 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:44421' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'original-open_dataset-umo-6221f1a659dbb227233c8f0082e0d466', 'original-open_dataset-umo-ecd592b75cc01866922d3077d06ac5fa'} (stimulus_id='handle-worker-cleanup-1758245281.1363976')
# 2025-09-19 11:28:01,159 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:03,915 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:46109 (pid=4142595) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:03,970 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:06,397 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:45325 (pid=4142632) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:06,459 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:06,707 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:38407 (pid=4142628) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:06,755 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:35863 (pid=4142636) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:06,774 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:06,805 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:08,495 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:38319 (pid=4142670) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:08,538 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:38319' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'original-open_dataset-umo-f74af81093b3a01fa8bae1cf3c615fa4'} (stimulus_id='handle-worker-cleanup-1758245288.5384178')
# 2025-09-19 11:28:08,550 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:08,864 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:38737 (pid=4142677) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:08,927 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:11,757 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:45185 (pid=4142716) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:11,819 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:12,003 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:38493 (pid=4142723) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:12,068 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:16,244 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:44883 (pid=4142778) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:16,287 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:44883' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-sum-sum-aggregate-mean_chunk-183fe4cd1df467827efcc315f5b5dc3a', 11, 0, 2), 'original-open_dataset-umo-9cb85f50adfa64ed1475641fed75f054'} (stimulus_id='handle-worker-cleanup-1758245296.2873259')
# 2025-09-19 11:28:16,307 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:16,712 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:38595 (pid=4142774) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:16,759 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:34443 (pid=4142838) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:16,789 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:16,827 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:16,967 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:33359 (pid=4142813) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:16,997 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:35581 (pid=4142807) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:17,005 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:33359' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('mean_chunk-183fe4cd1df467827efcc315f5b5dc3a', 16, 0, 2), ('mean_chunk-183fe4cd1df467827efcc315f5b5dc3a', 17, 0, 2), ('mean_chunk-183fe4cd1df467827efcc315f5b5dc3a', 18, 0, 2), ('mean_chunk-183fe4cd1df467827efcc315f5b5dc3a', 19, 0, 2)} (stimulus_id='handle-worker-cleanup-1758245297.0052366')
# 2025-09-19 11:28:17,013 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:17,041 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:35581' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'shuffle-sorter-1aeb640420f945411aa21959d3c38cad', 'original-open_dataset-vmo-2922bc81e68a980ef6879e26d6f689ec', ('mean_combine-partial-707d181f9c4905c7497f9fc62161e966', 5, 0, 2)} (stimulus_id='handle-worker-cleanup-1758245297.041272')
# 2025-09-19 11:28:17,054 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:17,068 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:40209 (pid=4142858) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:17,115 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:17,153 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:44729 (pid=4142831) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:17,201 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:44729' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('rechunk-merge-11dc4790778f88124baf0d4162e780ba', 0, 2), 'shuffle-taker-626337623fc64f402b35f5c79b66f2eb', 'original-open_dataset-vmo-4d40288f0a3ac6e13f477a4e463b39a1', 'original-open_dataset-vmo-131d595fe87e61df846d6acde8212f81', ('rechunk-merge-11dc4790778f88124baf0d4162e780ba', 0, 1), ('rechunk-merge-11dc4790778f88124baf0d4162e780ba', 0, 0), ('array-9d457c38cd345eaee732529f27b1b397', 0)} (stimulus_id='handle-worker-cleanup-1758245297.2013729')
# 2025-09-19 11:28:17,220 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:17,253 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:38349 (pid=4142863) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:17,254 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:42457 (pid=4142362) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:17,309 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:17,328 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:17,443 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:39367 (pid=4142770) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:17,491 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:39367' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'original-open_dataset-umo-6221f1a659dbb227233c8f0082e0d466', ('mean_combine-partial-707d181f9c4905c7497f9fc62161e966', 3, 0, 2)} (stimulus_id='handle-worker-cleanup-1758245297.4915466')
# 2025-09-19 11:28:17,501 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:17,558 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:41757 (pid=4142786) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:17,602 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:41757' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'shuffle-taker-6b55c9f78e4470b1be9bb1c9fec5f633'} (stimulus_id='handle-worker-cleanup-1758245297.601724')
# 2025-09-19 11:28:17,612 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:45791 (pid=4142802) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:17,614 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:17,662 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:45791' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'original-open_dataset-umo-a75c6616a1575009bf5e9218a16f495b', 'original-open_dataset-umo-1f0ac51b8519ef90758550b35f46ad06'} (stimulus_id='handle-worker-cleanup-1758245297.662561')
# 2025-09-19 11:28:17,676 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:17,953 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:40713 (pid=4142847) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:18,007 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:18,216 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:45717 (pid=4142783) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:18,263 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:45717' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('mean_chunk-183fe4cd1df467827efcc315f5b5dc3a', 9, 0, 2), ('mean_combine-partial-707d181f9c4905c7497f9fc62161e966', 1, 0, 2), 'original-open_dataset-umo-ecd592b75cc01866922d3077d06ac5fa'} (stimulus_id='handle-worker-cleanup-1758245298.2638147')
# 2025-09-19 11:28:18,279 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:19,700 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:39101 (pid=4142878) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:19,768 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:39101' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'shuffle-taker-ae20db758be2260df01fc28d134f7643', 'original-open_dataset-vmo-44e42b1eb51616d34521b6ba046e4a00'} (stimulus_id='handle-worker-cleanup-1758245299.7683604')
# 2025-09-19 11:28:19,781 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:20,266 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:39343 (pid=4142693) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:20,315 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:39343' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'original-open_dataset-umo-f8a85cdf1e2d05a1e9220b86783d28b6', 'original-open_dataset-umo-fd9d3aa604d5736b1ad824b76adf33df'} (stimulus_id='handle-worker-cleanup-1758245300.3153622')
# 2025-09-19 11:28:20,332 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:20,399 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:41985 (pid=4141813) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:20,468 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:41985' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'original-open_dataset-vmo-9e0af1852f358bd8a3fbaadcd8134757'} (stimulus_id='handle-worker-cleanup-1758245300.4686692')
# 2025-09-19 11:28:20,478 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:21,217 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:44829 (pid=4142738) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:21,250 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:44829' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'shuffle-taker-dfdfdea872dcd4b676f891eda6ba1456'} (stimulus_id='handle-worker-cleanup-1758245301.2506366')
# 2025-09-19 11:28:21,257 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:22,896 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:45587 (pid=4143025) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:22,953 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:24,995 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:42403 (pid=4143066) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:25,055 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:27,395 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:37389 (pid=4142792) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:27,450 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:37389' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('mean_chunk-183fe4cd1df467827efcc315f5b5dc3a', 8, 0, 2), ('mean_combine-partial-707d181f9c4905c7497f9fc62161e966', 0, 0, 2), ('mean_chunk-183fe4cd1df467827efcc315f5b5dc3a', 10, 0, 2)} (stimulus_id='handle-worker-cleanup-1758245307.4502864')
# 2025-09-19 11:28:27,463 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:27,609 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:42223 (pid=4142996) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:27,661 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:27,708 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:33211 (pid=4142843) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:27,765 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:28,403 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:33203 (pid=4143106) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:28,452 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:30,157 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:36161 (pid=4143101) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:30,220 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:32,766 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:43547 (pid=4143154) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:32,816 - distributed.scheduler - ERROR - Task ('open_dataset-umo-concatenate-08ce81061ea57cd4ad239efda670c8ad', 104, 0, 0, 1) marked as failed because 4 workers died while trying to run it
# 2025-09-19 11:28:32,877 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:33,048 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:37773 (pid=4143141) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:33,118 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:33,479 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:33371 (pid=4143146) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:33,646 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:34377 (pid=4143150) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:33,845 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:45291 (pid=4143158) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:33,849 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:38685 (pid=4143196) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:33,858 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:39757 (pid=4143176) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:35,117 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:35,128 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:35,148 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:38293 (pid=4143276) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:35,153 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:37089 (pid=4143226) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:35,154 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:34943 (pid=4143033) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:35,186 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:35,189 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:35,192 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:35,229 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:35,231 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:35,235 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:36,296 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:46791 (pid=4143330) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:36,342 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:36,360 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:44703 (pid=4143070) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:36,426 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:37,368 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:36727 (pid=4143341) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:37,420 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:38,216 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:43779 (pid=4143368) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:38,258 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:41,197 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:45093 (pid=4143426) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:41,247 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:42,943 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:41245 (pid=4143188) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:43,005 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:43,595 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:43915 (pid=4143346) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:43,654 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:44,495 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:43221 (pid=4143442) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:44,554 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:44,608 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:40741 (pid=4143451) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:44,676 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:45,705 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:37301 (pid=4143408) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:45,755 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 11:28:55,309 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:35073 (pid=4143447) exceeded 95% memory budget. Restarting...
# 2025-09-19 11:28:55,376 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:55:37,235 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:33143 (pid=4143702) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:55:37,319 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:55:43,246 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:34033 (pid=4143645) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:55:43,368 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:55:44,545 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:44111 (pid=4143162) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:55:44,588 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:37275 (pid=4143706) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:55:44,654 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:55:44,663 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:46085 (pid=4143520) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:55:44,668 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:55:44,739 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:55:44,741 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:32809 (pid=4143547) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:55:44,823 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:55:44,888 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:33165 (pid=4143555) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:55:44,989 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:55:45,845 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:37149 (pid=4143166) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:55:45,933 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:55:46,046 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:39539 (pid=4143572) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:55:46,167 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:55:46,210 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:38615 (pid=4143571) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:55:46,274 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:55:46,308 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:44033 (pid=4143671) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:55:46,431 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:55:47,335 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:44471 (pid=4143524) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:55:47,399 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:55:47,702 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:44557 (pid=4143541) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:55:47,789 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:39745 (pid=4143750) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:55:47,809 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:55:47,850 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:43501 (pid=4143192) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:55:47,886 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:55:47,931 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:55:48,100 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:36665 (pid=4143730) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:55:48,180 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:55:48,649 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:41205 (pid=4143567) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:55:48,741 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:55:49,501 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:33243 (pid=4143766) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:55:49,549 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:38337 (pid=4143499) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:55:49,594 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:55:49,631 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:55:50,044 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:43905 (pid=4143560) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:55:50,156 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:55:51,045 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:37841 (pid=4143171) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:55:51,126 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:55:51,795 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:44827 (pid=4143464) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:55:51,887 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:55:51,895 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:41941 (pid=4143641) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:55:51,984 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:55:52,993 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:44697 (pid=4143029) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:55:53,067 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:44697' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'shuffle-taker-357592500159f29cf33a2c98c6bd7e82'} (stimulus_id='handle-worker-cleanup-1758254153.0672402')
# 2025-09-19 13:55:53,094 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:55:56,400 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:34487 (pid=4143558) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:55:56,475 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:55:59,548 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:37805 (pid=4143665) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:55:59,662 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:55:59,686 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:39979 (pid=4143690) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:55:59,765 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:55:59,787 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:33337 (pid=4143724) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:55:59,887 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:05,435 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:43643 (pid=4145329) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:05,509 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:07,152 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:38081 (pid=4145364) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:07,223 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:08,488 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:38233 (pid=4145372) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:08,549 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:08,739 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:40099 (pid=4145368) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:08,819 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:10,210 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:46479 (pid=4145432) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:10,246 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:35515 (pid=4145414) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:10,320 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:10,325 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:10,386 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:36041 (pid=4145359) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:10,437 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:10,745 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:35561 (pid=4145422) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:10,801 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:11,049 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:36795 (pid=4145487) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:11,111 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:11,244 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:39361 (pid=4145355) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:11,314 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:11,345 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:39719 (pid=4145342) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:11,404 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:11,735 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:42147 (pid=4145464) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:11,785 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:12,288 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:34991 (pid=4145482) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:12,300 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:39865 (pid=4145495) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:12,383 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:12,392 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:12,800 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:36201 (pid=4145477) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:12,808 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:34595 (pid=4145427) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:12,844 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:33167 (pid=4145574) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:12,883 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:12,900 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:12,912 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:14,100 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:38747 (pid=4145552) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:14,159 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:14,948 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:37315 (pid=4145557) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:15,007 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:18,194 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:35001 (pid=4145618) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:18,236 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:35001' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'shuffle-taker-357592500159f29cf33a2c98c6bd7e82'} (stimulus_id='handle-worker-cleanup-1758254178.2364497')
# 2025-09-19 13:56:18,249 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:18,287 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:38213 (pid=4145623) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:18,340 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:21,710 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:41259 (pid=4145680) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:21,774 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:23,493 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:36553 (pid=4145658) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:23,555 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:23,745 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:44939 (pid=4145608) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:23,823 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:26,088 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:38015 (pid=4145705) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:26,150 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:27,934 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:42107 (pid=4145740) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:28,004 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:29,244 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:45213 (pid=4145518) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:29,251 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:35415 (pid=4145695) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:29,334 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:29,337 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:30,852 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:33169 (pid=4145753) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:30,886 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:46003 (pid=4145700) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:30,966 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:30,972 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:31,295 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:42257 (pid=4145767) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:31,365 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:32,986 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:35435 (pid=4145805) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:33,058 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:33,340 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:37479 (pid=4145772) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:33,420 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:33,445 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:38993 (pid=4145795) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:33,511 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:33,651 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:43789 (pid=4145812) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:33,732 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:33,835 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:35031 (pid=4145856) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:33,958 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:34,444 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:37177 (pid=4145829) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:34,447 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:44983 (pid=4145837) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:34,509 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:34,513 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:35,108 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:40231 (pid=4145799) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:35,182 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:35,651 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:44701 (pid=4145931) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:35,787 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:36,501 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:43367 (pid=4145927) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:36,552 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:36,900 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:40051 (pid=4145892) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:36,958 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:37,900 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:45545 (pid=4145981) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:37,975 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:39,088 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:45853 (pid=4145896) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:39,166 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:40,849 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:41011 (pid=4145990) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:40,888 - distributed.scheduler - ERROR - Task ('open_dataset-vmo-original-concatenate-40628b8ac8ea8bd55fb7a9588f797737', 111, 0, 0, 0) marked as failed because 4 workers died while trying to run it
# 2025-09-19 13:56:40,889 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:41011' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'shuffle-taker-357592500159f29cf33a2c98c6bd7e82'} (stimulus_id='handle-worker-cleanup-1758254200.8882537')
# 2025-09-19 13:56:40,926 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:42,095 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:33185 (pid=4146030) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:42,154 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:44,387 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:37113 (pid=4146035) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:44,458 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:45,000 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:40375 (pid=4146061) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:45,063 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:46,493 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:44451 (pid=4146075) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:46,545 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:48,387 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:46441 (pid=4146105) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:48,432 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:49,908 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:39555 (pid=4145923) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:49,973 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:50,945 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:34537 (pid=4146136) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:51,049 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:51,251 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:37341 (pid=4146138) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:51,315 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:51,650 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:41013 (pid=4145818) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:51,768 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:52,335 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:36061 (pid=4146120) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:52,393 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:53,286 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:35855 (pid=4146166) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:53,365 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:53,689 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:32947 (pid=4146174) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:53,759 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:53,852 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:46473 (pid=4146162) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:53,897 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:55,545 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:34713 (pid=4146219) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:55,602 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:55,635 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:43401 (pid=4146236) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:55,763 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:55,987 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:35005 (pid=4146208) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:56,042 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:37457 (pid=4146214) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:56,048 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:56,098 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:57,244 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:38311 (pid=4146080) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:57,310 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:57,344 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:35123 (pid=4146313) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:57,424 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:57,445 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:43287 (pid=4146260) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:57,507 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:57,844 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:38095 (pid=4146263) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:57,920 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:58,901 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:44833 (pid=4146344) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:58,963 - distributed.nanny - WARNING - Restarting worker
# 2025-09-19 13:56:59,509 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:46363 (pid=4146288) exceeded 95% memory budget. Restarting...
# 2025-09-19 13:56:59,573 - distributed.nanny - WARNING - Restarting worker

# %% [markdown]
# Load datastore

# %%
esm_datastore = intake.open_esm_datastore(
    "/g/data/ol01/cy8964/access-om3/archive/8km_jra_ryf_obc_Charrassin/experiment_datastore.json", 
    columns_with_iterables=[
            "variable",
            "variable_long_name",
            "variable_standard_name",
            "variable_cell_methods",
            "variable_units",
    ] # This is important
)

# %% [markdown]
# Load month 0 specific datastore to get y axis info

# %%
mo0_esm_datastore = intake.open_esm_datastore(
    "/g/data/ol01/cy8964/access-om3/datastores/8km_jra_ryf_obc_Charrassin-output000/experiment_datastore.json", 
    columns_with_iterables=[
            "variable",
            "variable_long_name",
            "variable_standard_name",
            "variable_cell_methods",
            "variable_units",
    ] # This is important
)

ds_good_yh = mo0_esm_datastore.search(variable="umo_2d").to_dask(xarray_open_kwargs={'decode_timedelta':True})
good_yh_coords = ds_good_yh.yh.copy().load()
ds_good_yq = mo0_esm_datastore.search(variable="vmo_2d").to_dask(xarray_open_kwargs={'decode_timedelta':True})
good_yq_coords = ds_good_yq.yq.copy().load()
def reset_y_coords(ds): #thanks to Jemma Jeffree for helping make this work!!
    ds = ds.assign_coords({'yh':good_yh_coords})
    ds = ds.assign_coords({'yq':good_yq_coords})
    return ds

# %% [markdown]
# When loading data that has a y-axis, you need to use the `preprocess` (and likely `decode_timedelta` too) arguments:
# ```
# esm_datastore.search(variable="").to_dask(preprocess=reset_y_coords,xarray_open_kwargs={'decode_timedelta':True})
# ```

# %%
'''
names of panant models
panant-01-zstar-ACCESSyr2
panant-005-zstar-ACCESSyr2
panant-0025-zstar-ACCESSyr2
'''
catalog = intake.cat.access_nri

density_threshold = 1037.18

# %% [markdown]
# ## Open panant-01-zstar-ACCESSyr2 data and process:

# %%
lat_slice = slice(-90,-59)
expt = 'panant-01-zstar-ACCESSyr2'

# %%
# open umo, vmo:

var_search = catalog[expt].search(variable='vmo', frequency="1mon")
dset = var_search.to_dask(xarray_open_kwargs={'decode_timedelta' : False})
darray = dset['vmo']
time_slice = np.arange(8*12,9*12+12)
vmo = darray.chunk(chunks={"time": -1}).isel(time=time_slice)

var_search = catalog[expt].search(variable='umo', frequency="1mon")
dset = var_search.to_dask(xarray_open_kwargs={'decode_timedelta' : False})
darray = dset['umo']
umo = darray.chunk(chunks={"time": -1}).isel(time=time_slice)
# Out:
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/intake_esm/core.py:259: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   records = grouped.get_group(internal_key).to_dict(orient='records')
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/intake_esm/core.py:259: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   records = grouped.get_group(internal_key).to_dict(orient='records')

# %%
# select latitude and density ranges, sum over density, annual averages:
vmo = vmo.sel(yq=lat_slice).sel(rho2_l=slice(density_threshold, None)).sum('rho2_l').mean('time')
vmo = vmo.isel(yq=slice(1, None))
umo = umo.sel(yh=lat_slice).sel(rho2_l=slice(density_threshold, None)).sum('rho2_l').mean('time')
umo = umo.isel(xq=slice(1, None))

# %%
# open contour data:
outfile = ('/g/data/g40/akm157/model_data/access-om2/Antarctic_slope_contour_1000m.npz')
data = np.load(outfile)
mask_y_transport = data['mask_y_transport']
mask_x_transport = data['mask_x_transport']
mask_y_transport_numbered = data['mask_y_transport_numbered']
mask_x_transport_numbered = data['mask_x_transport_numbered']

yh = umo.yh
yq = vmo.yq
xh = vmo.xh
xq = umo.xq

# Convert contour masks to data arrays, so we can multiply them later.
# We need to ensure the lat lon coordinates correspond to the actual data location:
#       The y masks are used for vmo, so like vmo this should have dimensions (yq, xh).
#       The x masks are used for umo, so like umo this should have dimensions (yh, xq).
#       However the actual name will always be simply y or x irrespective of the variable
#       to make concatenation of transports in both direction and sorting possible.
mask_x_transport = xr.DataArray(
    mask_x_transport, coords=[('y', yh.data), ('x', xq.data)])
mask_y_transport = xr.DataArray(
    mask_y_transport, coords=[('y', yq.data), ('x', xh.data)])
mask_x_transport_numbered = xr.DataArray(
    mask_x_transport_numbered, coords=[('y', yh.data), ('x', xq.data)])
mask_y_transport_numbered = xr.DataArray(
    mask_y_transport_numbered, coords=[('y', yq.data), ('x', xh.data)])

# number of points along contour:
num_points = int(np.maximum(
    np.max(mask_y_transport_numbered),np.max(mask_x_transport_numbered)))

# stack contour data into 1d:
mask_x_numbered_1d = mask_x_transport_numbered.stack(contour_index = ['y', 'x'])
mask_x_numbered_1d = mask_x_numbered_1d.where(mask_x_numbered_1d > 0, drop = True)
mask_y_numbered_1d = mask_y_transport_numbered.stack(contour_index = ['y', 'x'])
mask_y_numbered_1d = mask_y_numbered_1d.where(mask_y_numbered_1d > 0, drop = True)
contour_ordering = xr.concat((mask_x_numbered_1d,mask_y_numbered_1d), dim = 'contour_index')
contour_ordering = contour_ordering.sortby(contour_ordering)
contour_index_array = np.arange(1, len(contour_ordering)+1)

# %%
rho_0 = 1035.0

# Note that vmo is Ocean Mass Y Transport (kg s-1) and defined as the transport across
# the northern edge of a tracer cell so its coordinates should be (yq, xh).
# umo is Ocean Mass X Transport (kg s-1) and defined as the transport across
# the eastern edge of a tracer cell so its coordinates should be (yh, xq).
# However we will keep the actual name as simply y/x irrespective of the variable
# to make concatenation and sorting possible.
vmo = vmo.rename({'yq':'y', 'xh':'x'})
umo = umo.rename({'yh':'y', 'xq':'x'})

# convert kg/s to Sv and multiply by contour masks
vmo = (vmo/(1e6*rho_0)*mask_y_transport).compute()
umo = (umo/(1e6*rho_0)*mask_x_transport).compute()

# stack transports into 1d and drop any points not on contour:
x_transport_1d = umo.stack(contour_index=['y', 'x'])
x_transport_1d = x_transport_1d.where(mask_x_numbered_1d>0, drop=True)
y_transport_1d = vmo.stack(contour_index=['y', 'x'])
y_transport_1d = y_transport_1d.where(mask_y_numbered_1d>0, drop=True)

# combine all points on contour:
vol_trans_across_contour = xr.concat((x_transport_1d, y_transport_1d), dim='contour_index')
vol_trans_across_contour = vol_trans_across_contour.sortby(contour_ordering)
vol_trans_across_contour = vol_trans_across_contour.drop_vars({'x', 'contour_index', 'y'})
vol_trans_across_contour.coords['contour_index'] = contour_index_array
vol_trans_across_contour = (vol_trans_across_contour).compute()
# Out:
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/client.py:3363: UserWarning: Sending large graph of size 13.21 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/client.py:3363: UserWarning: Sending large graph of size 13.21 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(

# %%
panan01_DSW_trans = vol_trans_across_contour.copy()
panan01_DSW_trans.cumsum().plot()

'''save_dir = '/g/data/g40/akm157/model_data/mom6/panant-01-zstar-ACCESSyr2/cross_slope_transport_yr8_10.nc'

ds = xr.Dataset({'panan01_DSW_trans': panan01_DSW_trans})

ds.to_netcdf(save_dir)'''
# Out:
# "save_dir = '/g/data/g40/akm157/model_data/mom6/panant-01-zstar-ACCESSyr2/cross_slope_transport_yr8_10.nc'\n\nds = xr.Dataset({'panan01_DSW_trans': panan01_DSW_trans})\n\nds.to_netcdf(save_dir)"

# %% [markdown]
# ## Open panant-005-zstar-ACCESSyr2 data and process:

# %%
lat_slice = slice(-90,-59)
expt = 'panant-005-zstar-ACCESSyr2'

# %%
# open umo, vmo:

chunks_dict = {
    'time' : -1,
    'rho2_l' : -1,
    'yh' : -1,
    'xq' : -1,
    'yq' : -1,
    'xh' : -1,
}

var_search = catalog[expt].search(variable='vmo', frequency="1mon")
dset = var_search.to_dask(xarray_open_kwargs={'decode_timedelta' : False})
#dset = var_search.to_dask(xarray_open_kwargs={'chunks' : chunks_dict, 'decode_timedelta' : False})
darray = dset['vmo']
time_slice = np.arange(8*12,9*12+12)
#vmo = darray.isel(time=time_slice)
vmo = darray.chunk(chunks={"time": -1}).isel(time=time_slice)

var_search = catalog[expt].search(variable='umo', frequency="1mon")
dset = var_search.to_dask(xarray_open_kwargs={'decode_timedelta' : False})
darray = dset['umo']
umo = darray.chunk(chunks={"time": -1}).isel(time=time_slice)
# Out:
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/intake_esm/core.py:259: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   records = grouped.get_group(internal_key).to_dict(orient='records')
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/intake_esm/core.py:259: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   records = grouped.get_group(internal_key).to_dict(orient='records')

# %%
# select latitude and density ranges, sum over density, annual averages:
vmo = vmo.sel(yq=lat_slice).sel(rho2_l=slice(density_threshold, None)).sum('rho2_l').mean('time')
vmo = vmo.isel(yq=slice(1, None)).load()
umo = umo.sel(yh=lat_slice).sel(rho2_l=slice(density_threshold, None)).sum('rho2_l').mean('time')
umo = umo.isel(xq=slice(1, None)).load()
# Out:
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/client.py:3363: UserWarning: Sending large graph of size 38.69 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/client.py:3363: UserWarning: Sending large graph of size 38.69 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(

# %%
# open contour data:
isobath_dir = ('/g/data/g40/akm157/model_data/mom6/panan/isobath_1000m_panan005.nc')

data = xr.open_dataset(isobath_dir)
mask_y_transport = data.mask_y_transport
mask_x_transport = data.mask_x_transport
mask_y_transport_numbered = data.mask_y_transport_numbered
mask_x_transport_numbered = data.mask_x_transport_numbered

yh = umo.yh
yq = vmo.yq
xh = vmo.xh
xq = umo.xq

# Convert contour masks to data arrays, so we can multiply them later.
# We need to ensure the lat lon coordinates correspond to the actual data location:
#       The y masks are used for vmo, so like vmo this should have dimensions (yq, xh).
#       The x masks are used for umo, so like umo this should have dimensions (yh, xq).
#       However the actual name will always be simply y or x irrespective of the variable
#       to make concatenation of transports in both direction and sorting possible.
mask_x_transport = xr.DataArray(
    mask_x_transport.values, coords=[('y', yh.data), ('x', xq.data)])
mask_y_transport = xr.DataArray(
    mask_y_transport.values, coords=[('y', yq.data), ('x', xh.data)])
mask_x_transport_numbered = xr.DataArray(
    mask_x_transport_numbered.values, coords=[('y', yh.data), ('x', xq.data)])
mask_y_transport_numbered = xr.DataArray(
    mask_y_transport_numbered.values, coords=[('y', yq.data), ('x', xh.data)])

# number of points along contour:
num_points = int(np.maximum(
    np.max(mask_y_transport_numbered),np.max(mask_x_transport_numbered)))

# stack contour data into 1d:
mask_x_numbered_1d = mask_x_transport_numbered.stack(contour_index = ['y', 'x'])
mask_x_numbered_1d = mask_x_numbered_1d.where(mask_x_numbered_1d > 0, drop = True)
mask_y_numbered_1d = mask_y_transport_numbered.stack(contour_index = ['y', 'x'])
mask_y_numbered_1d = mask_y_numbered_1d.where(mask_y_numbered_1d > 0, drop = True)
contour_ordering = xr.concat((mask_x_numbered_1d,mask_y_numbered_1d), dim = 'contour_index')
contour_ordering = contour_ordering.sortby(contour_ordering)
contour_index_array = np.arange(1, len(contour_ordering)+1)

# %%
rho_0 = 1035.0

# Note that vmo is Ocean Mass Y Transport (kg s-1) and defined as the transport across
# the northern edge of a tracer cell so its coordinates should be (yq, xh).
# umo is Ocean Mass X Transport (kg s-1) and defined as the transport across
# the eastern edge of a tracer cell so its coordinates should be (yh, xq).
# However we will keep the actual name as simply y/x irrespective of the variable
# to make concatenation and sorting possible.
vmo = vmo.rename({'yq':'y', 'xh':'x'})
umo = umo.rename({'yh':'y', 'xq':'x'})

# convert kg/s to Sv and multiply by contour masks
vmo = (vmo/(1e6*rho_0)*mask_y_transport)#.compute()
umo = (umo/(1e6*rho_0)*mask_x_transport)#.compute()

# stack transports into 1d and drop any points not on contour:
x_transport_1d = umo.stack(contour_index=['y', 'x'])
x_transport_1d = x_transport_1d.where(mask_x_numbered_1d>0, drop=True)
y_transport_1d = vmo.stack(contour_index=['y', 'x'])
y_transport_1d = y_transport_1d.where(mask_y_numbered_1d>0, drop=True)

# combine all points on contour:
vol_trans_across_contour = xr.concat((x_transport_1d, y_transport_1d), dim='contour_index')
vol_trans_across_contour = vol_trans_across_contour.sortby(contour_ordering)
vol_trans_across_contour = vol_trans_across_contour.drop_vars({'x', 'contour_index', 'y'})
vol_trans_across_contour.coords['contour_index'] = contour_index_array
vol_trans_across_contour = (vol_trans_across_contour).compute()
# Out:
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/client.py:3363: UserWarning: Sending large graph of size 57.05 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# 2025-09-19 11:27:41,065 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.30 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:27:41,215 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.23 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:27:41,228 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.33 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:27:41,443 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.31 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:27:41,485 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.22 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:27:41,547 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.36 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:27:41,807 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.22 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:27:42,085 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.25 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:27:42,698 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.30 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:27:42,715 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.24 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:27:42,949 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.22 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:27:42,965 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.33 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:27:43,058 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.29 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:27:43,151 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.25 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:27:43,207 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.33 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:27:43,529 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.26 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:27:43,609 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.23 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:27:44,014 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 3.67 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:27:45,878 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.30 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:27:47,030 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:34931
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1485, in connect
#     return await self._connect(addr=addr, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1429, in _connect
#     comm = await connect(
#            ^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/comm/core.py", line 342, in connect
#     comm = await wait_for(
#            ^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/utils.py", line 1923, in wait_for
#     return await fut
#            ^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 547, in connect
#     stream = await self.client.connect(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/tornado/tcpclient.py", line 279, in connect
#     af, addr, stream = await connector.start(connect_timeout=timeout)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1476, in connect
#     async with asyncio.timeout(math.inf) as scope:
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/worker.py", line 2073, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/worker.py", line 2876, in get_data_from_worker
#     comm = await rpc.connect(worker)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1497, in connect
#     raise CommClosedError(reason)
# distributed.comm.core.CommClosedError: Address removed.
# 2025-09-19 11:27:47,437 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:42915
# ConnectionRefusedError: [Errno 111] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/comm/core.py", line 342, in connect
#     comm = await wait_for(
#            ^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/utils.py", line 1923, in wait_for
#     return await fut
#            ^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 560, in connect
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <distributed.comm.tcp.TCPConnector object at 0x15521912cd50>: ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1485, in connect
#     return await self._connect(addr=addr, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1429, in _connect
#     comm = await connect(
#            ^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/comm/core.py", line 366, in connect
#     await asyncio.sleep(backoff)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/asyncio/tasks.py", line 649, in sleep
#     return await future
#            ^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1476, in connect
#     async with asyncio.timeout(math.inf) as scope:
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/worker.py", line 2073, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/worker.py", line 2876, in get_data_from_worker
#     comm = await rpc.connect(worker)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1497, in connect
#     raise CommClosedError(reason)
# distributed.comm.core.CommClosedError: Address removed.
# 2025-09-19 11:27:47,856 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:42995
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1485, in connect
#     return await self._connect(addr=addr, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1429, in _connect
#     comm = await connect(
#            ^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/comm/core.py", line 342, in connect
#     comm = await wait_for(
#            ^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/utils.py", line 1923, in wait_for
#     return await fut
#            ^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 547, in connect
#     stream = await self.client.connect(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/tornado/tcpclient.py", line 279, in connect
#     af, addr, stream = await connector.start(connect_timeout=timeout)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1476, in connect
#     async with asyncio.timeout(math.inf) as scope:
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/worker.py", line 2073, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/worker.py", line 2876, in get_data_from_worker
#     comm = await rpc.connect(worker)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1497, in connect
#     raise CommClosedError(reason)
# distributed.comm.core.CommClosedError: Address removed.
# 2025-09-19 11:27:47,861 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:46621
# ConnectionRefusedError: [Errno 111] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/comm/core.py", line 342, in connect
#     comm = await wait_for(
#            ^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/utils.py", line 1923, in wait_for
#     return await fut
#            ^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 560, in connect
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <distributed.comm.tcp.TCPConnector object at 0x14a1427c9d50>: ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1485, in connect
#     return await self._connect(addr=addr, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1429, in _connect
#     comm = await connect(
#            ^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/comm/core.py", line 366, in connect
#     await asyncio.sleep(backoff)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/asyncio/tasks.py", line 649, in sleep
#     return await future
#            ^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1476, in connect
#     async with asyncio.timeout(math.inf) as scope:
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/worker.py", line 2073, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/worker.py", line 2876, in get_data_from_worker
#     comm = await rpc.connect(worker)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1497, in connect
#     raise CommClosedError(reason)
# distributed.comm.core.CommClosedError: Address removed.
# 2025-09-19 11:27:48,653 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.29 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:27:48,701 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.28 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:27:48,772 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.29 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:27:48,952 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:35317
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1485, in connect
#     return await self._connect(addr=addr, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1429, in _connect
#     comm = await connect(
#            ^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/comm/core.py", line 342, in connect
#     comm = await wait_for(
#            ^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/utils.py", line 1923, in wait_for
#     return await fut
#            ^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 547, in connect
#     stream = await self.client.connect(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/tornado/tcpclient.py", line 279, in connect
#     af, addr, stream = await connector.start(connect_timeout=timeout)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1476, in connect
#     async with asyncio.timeout(math.inf) as scope:
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/worker.py", line 2073, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/worker.py", line 2876, in get_data_from_worker
#     comm = await rpc.connect(worker)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1497, in connect
#     raise CommClosedError(reason)
# distributed.comm.core.CommClosedError: Address removed.
# 2025-09-19 11:27:50,377 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.28 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:27:50,658 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.32 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:27:51,460 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 3.76 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:27:51,853 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.29 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:27:52,092 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:42315
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1485, in connect
#     return await self._connect(addr=addr, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1429, in _connect
#     comm = await connect(
#            ^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/comm/core.py", line 342, in connect
#     comm = await wait_for(
#            ^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/utils.py", line 1923, in wait_for
#     return await fut
#            ^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 547, in connect
#     stream = await self.client.connect(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/tornado/tcpclient.py", line 279, in connect
#     af, addr, stream = await connector.start(connect_timeout=timeout)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1476, in connect
#     async with asyncio.timeout(math.inf) as scope:
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/worker.py", line 2073, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/worker.py", line 2876, in get_data_from_worker
#     comm = await rpc.connect(worker)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1497, in connect
#     raise CommClosedError(reason)
# distributed.comm.core.CommClosedError: Address removed.
# 2025-09-19 11:27:52,548 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.20 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:27:53,796 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.25 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:27:54,407 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.30 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:27:54,511 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:37915
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1485, in connect
#     return await self._connect(addr=addr, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1429, in _connect
#     comm = await connect(
#            ^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/comm/core.py", line 342, in connect
#     comm = await wait_for(
#            ^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/utils.py", line 1923, in wait_for
#     return await fut
#            ^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 547, in connect
#     stream = await self.client.connect(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/tornado/tcpclient.py", line 279, in connect
#     af, addr, stream = await connector.start(connect_timeout=timeout)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1476, in connect
#     async with asyncio.timeout(math.inf) as scope:
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/worker.py", line 2073, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/worker.py", line 2876, in get_data_from_worker
#     comm = await rpc.connect(worker)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1497, in connect
#     raise CommClosedError(reason)
# distributed.comm.core.CommClosedError: Address removed.
# 2025-09-19 11:27:58,580 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.27 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:27:58,719 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.30 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:27:58,809 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.32 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:27:58,921 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.26 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:27:59,083 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 3.67 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:27:59,132 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.23 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:27:59,266 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 3.76 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:27:59,285 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 3.71 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:27:59,354 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 3.67 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:27:59,572 - distributed.worker.memory - WARNING - Worker is at 83% memory usage. Pausing worker.  Process memory: 3.82 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:27:59,599 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.26 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:27:59,769 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.40 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:27:59,835 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.35 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:27:59,844 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.32 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:27:59,988 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.22 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:28:00,042 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 3.66 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:28:00,092 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:40333
# ConnectionRefusedError: [Errno 111] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/comm/core.py", line 342, in connect
#     comm = await wait_for(
#            ^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/utils.py", line 1923, in wait_for
#     return await fut
#            ^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 560, in connect
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <distributed.comm.tcp.TCPConnector object at 0x154d06a18cd0>: ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1485, in connect
#     return await self._connect(addr=addr, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1429, in _connect
#     comm = await connect(
#            ^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/comm/core.py", line 366, in connect
#     await asyncio.sleep(backoff)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/asyncio/tasks.py", line 649, in sleep
#     return await future
#            ^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1476, in connect
#     async with asyncio.timeout(math.inf) as scope:
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/worker.py", line 2073, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/worker.py", line 2876, in get_data_from_worker
#     comm = await rpc.connect(worker)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1497, in connect
#     raise CommClosedError(reason)
# distributed.comm.core.CommClosedError: Address removed.
# 2025-09-19 11:28:00,097 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:36375
# ConnectionRefusedError: [Errno 111] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/comm/core.py", line 342, in connect
#     comm = await wait_for(
#            ^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/utils.py", line 1923, in wait_for
#     return await fut
#            ^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 560, in connect
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <distributed.comm.tcp.TCPConnector object at 0x154d06b7ab10>: ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1485, in connect
#     return await self._connect(addr=addr, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1429, in _connect
#     comm = await connect(
#            ^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/comm/core.py", line 366, in connect
#     await asyncio.sleep(backoff)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/asyncio/tasks.py", line 649, in sleep
#     return await future
#            ^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1476, in connect
#     async with asyncio.timeout(math.inf) as scope:
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/worker.py", line 2073, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/worker.py", line 2876, in get_data_from_worker
#     comm = await rpc.connect(worker)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1497, in connect
#     raise CommClosedError(reason)
# distributed.comm.core.CommClosedError: Address removed.
# 2025-09-19 11:28:00,153 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.36 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:28:00,168 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.26 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:28:00,169 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.37 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:28:00,177 - distributed.worker.memory - WARNING - Worker is at 83% memory usage. Pausing worker.  Process memory: 3.81 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:28:00,234 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 3.75 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:28:00,243 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 3.78 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:28:00,262 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:36375
# ConnectionRefusedError: [Errno 111] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/comm/core.py", line 342, in connect
#     comm = await wait_for(
#            ^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/utils.py", line 1923, in wait_for
#     return await fut
#            ^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 560, in connect
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <distributed.comm.tcp.TCPConnector object at 0x14ab3f98aed0>: ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1485, in connect
#     return await self._connect(addr=addr, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1429, in _connect
#     comm = await connect(
#            ^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/comm/core.py", line 366, in connect
#     await asyncio.sleep(backoff)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/asyncio/tasks.py", line 649, in sleep
#     return await future
#            ^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1476, in connect
#     async with asyncio.timeout(math.inf) as scope:
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/worker.py", line 2073, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/worker.py", line 2876, in get_data_from_worker
#     comm = await rpc.connect(worker)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1497, in connect
#     raise CommClosedError(reason)
# distributed.comm.core.CommClosedError: Address removed.
# 2025-09-19 11:28:00,340 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.26 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:28:00,359 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.33 GiB -- Worker memory limit: 4.57 GiB
# ...
# 2025-09-19 11:28:34,884 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 3.70 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:28:34,913 - distributed.worker.memory - WARNING - Worker is at 6% memory usage. Resuming worker. Process memory: 281.42 MiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:28:35,065 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:37773
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1485, in connect
#     return await self._connect(addr=addr, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1429, in _connect
#     comm = await connect(
#            ^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/comm/core.py", line 342, in connect
#     comm = await wait_for(
#            ^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/utils.py", line 1923, in wait_for
#     return await fut
#            ^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 547, in connect
#     stream = await self.client.connect(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/tornado/tcpclient.py", line 279, in connect
#     af, addr, stream = await connector.start(connect_timeout=timeout)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1476, in connect
#     async with asyncio.timeout(math.inf) as scope:
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/worker.py", line 2073, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/worker.py", line 2876, in get_data_from_worker
#     comm = await rpc.connect(worker)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1497, in connect
#     raise CommClosedError(reason)
# distributed.comm.core.CommClosedError: Address removed.
# 2025-09-19 11:28:35,092 - distributed.worker.memory - WARNING - Worker is at 55% memory usage. Resuming worker. Process memory: 2.52 GiB -- Worker memory limit: 4.57 GiB
# ---------------------------------------------------------------------------
# KilledWorker                              Traceback (most recent call last)
# Cell In[13], line 27
#      25 vol_trans_across_contour = vol_trans_across_contour.drop_vars({'x', 'contour_index', 'y'})
#      26 vol_trans_across_contour.coords['contour_index'] = contour_index_array
# ---> 27 vol_trans_across_contour = (vol_trans_across_contour).compute()
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/xarray/core/dataarray.py:1189, in DataArray.compute(self, **kwargs)
#    1164 """Manually trigger loading of this array's data from disk or a
#    1165 remote source into memory and return a new array.
#    1166
#    (...)
#    1186 dask.compute
#    1187 """
#    1188 new = self.copy(deep=False)
# -> 1189 return new.load(**kwargs)
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/xarray/core/dataarray.py:1157, in DataArray.load(self, **kwargs)
#    1137 def load(self, **kwargs) -> Self:
#    1138     """Manually trigger loading of this array's data from disk or a
#    1139     remote source into memory and return this array.
#    1140
#    (...)
#    1155     dask.compute
#    1156     """
# -> 1157     ds = self._to_temp_dataset().load(**kwargs)
#    1158     new = self._from_temp_dataset(ds)
#    1159     self._variable = new._variable
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/xarray/core/dataset.py:542, in Dataset.load(self, **kwargs)
#     539 chunkmanager = get_chunked_array_type(*lazy_data.values())
#     541 # evaluate all the chunked arrays simultaneously
# --> 542 evaluated_data: tuple[np.ndarray[Any, Any], ...] = chunkmanager.compute(
#     543     *lazy_data.values(), **kwargs
#     544 )
#     546 for k, data in zip(lazy_data, evaluated_data, strict=False):
#     547     self.variables[k].data = data
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/xarray/namedarray/daskmanager.py:85, in DaskManager.compute(self, *data, **kwargs)
#      80 def compute(
#      81     self, *data: Any, **kwargs: Any
#      82 ) -> tuple[np.ndarray[Any, _DType_co], ...]:
#      83     from dask.array import compute
# ---> 85     return compute(*data, **kwargs)
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/dask/base.py:681, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     678     expr = expr.optimize()
#     679     keys = list(flatten(expr.__dask_keys__()))
# --> 681     results = schedule(expr, keys, **kwargs)
#     683 return repack(results)
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/client.py:2409, in Client._gather(self, futures, errors, direct, local_worker)
#    2407     exception = st.exception
#    2408     traceback = st.traceback
# -> 2409     raise exception.with_traceback(traceback)
#    2410 if errors == "skip":
#    2411     bad_keys.add(key)
#
# KilledWorker: Attempted to run task ('open_dataset-umo-concatenate-08ce81061ea57cd4ad239efda670c8ad', 104, 0, 0, 1) on 4 different workers, but all those workers died while running it. The last worker that attempt to run the task was tcp://127.0.0.1:43547. Inspecting worker logs is often a good next step to diagnose what went wrong. For more information see https://distributed.dask.org/en/stable/killed.html.
# 2025-09-19 11:28:35,174 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:39757
# ConnectionRefusedError: [Errno 111] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/comm/core.py", line 342, in connect
#     comm = await wait_for(
#            ^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/utils.py", line 1923, in wait_for
#     return await fut
#            ^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 560, in connect
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <distributed.comm.tcp.TCPConnector object at 0x1550cbc8e610>: ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1485, in connect
#     return await self._connect(addr=addr, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1429, in _connect
#     comm = await connect(
#            ^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/comm/core.py", line 366, in connect
#     await asyncio.sleep(backoff)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/asyncio/tasks.py", line 649, in sleep
#     return await future
#            ^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1476, in connect
#     async with asyncio.timeout(math.inf) as scope:
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/worker.py", line 2073, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/worker.py", line 2876, in get_data_from_worker
#     comm = await rpc.connect(worker)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1497, in connect
#     raise CommClosedError(reason)
# distributed.comm.core.CommClosedError: Address removed.
# 2025-09-19 11:28:35,772 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.23 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:28:35,778 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.29 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:28:36,078 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 3.73 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:28:36,183 - distributed.worker.memory - WARNING - Worker is at 83% memory usage. Pausing worker.  Process memory: 3.82 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:28:36,901 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.35 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:28:37,275 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 3.79 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:28:37,652 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.23 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:28:38,021 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 3.67 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:28:40,685 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.34 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:28:40,988 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 3.79 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:28:42,422 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.35 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:28:42,767 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 3.78 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:28:43,064 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.33 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:28:43,414 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 3.71 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:28:43,979 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.33 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:28:44,033 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.25 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:28:44,307 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 3.72 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:28:44,397 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 3.69 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:28:45,167 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.31 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:28:45,473 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 3.78 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:28:54,715 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.20 GiB -- Worker memory limit: 4.57 GiB
# 2025-09-19 11:28:55,169 - distributed.worker.memory - WARNING - Worker is at 83% memory usage. Pausing worker.  Process memory: 3.80 GiB -- Worker memory limit: 4.57 GiB

# %%
panan005_DSW_trans = vol_trans_across_contour.copy()
panan005_DSW_trans.cumsum().plot()

'''save_dir = '/g/data/g40/akm157/model_data/mom6/panant-005-zstar-ACCESSyr2/cross_slope_transport_yr8_10.nc'

ds = xr.Dataset({'panan005_DSW_trans': panan005_DSW_trans})

ds.to_netcdf(save_dir)'''
# Out:
# "save_dir = '/g/data/g40/akm157/model_data/mom6/panant-005-zstar-ACCESSyr2/cross_slope_transport_yr8_10.nc'\n\nds = xr.Dataset({'panan005_DSW_trans': panan005_DSW_trans})\n\nds.to_netcdf(save_dir)"

# %% [markdown]
# ## Open 8km_jra_ryf_obc_Charrassin data and process:

# %%
lat_slice = slice(-90,-59)
expt = '8km_jra_ryf_obc_Charrassin'

# %%
# open umo, vmo:

var_search = esm_datastore.search(variable='vmo', frequency="1mon")
dset = var_search.to_dask(preprocess=reset_y_coords, xarray_open_kwargs={'decode_timedelta':True})
darray = dset['vmo']
time_slice = np.arange(8*12,9*12+12)
vmo = darray.chunk(chunks={"time": -1}).isel(time=time_slice)

var_search = esm_datastore.search(variable='umo', frequency="1mon")
dset = var_search.to_dask(preprocess=reset_y_coords,xarray_open_kwargs={'decode_timedelta':True})# 'chunks' : chunks_dict, 
darray = dset['umo']
umo = darray.chunk(chunks={"time": -1}).isel(time=time_slice)
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %%
# select latitude and density ranges, sum over density, annual averages:
vmo = vmo.sel(yq=lat_slice).sel(rho2_l=slice(density_threshold, None)).sum('rho2_l').mean('time')
vmo = vmo.isel(yq=slice(1, None)).load()
umo = umo.sel(yh=lat_slice).sel(rho2_l=slice(density_threshold, None)).sum('rho2_l').mean('time')
umo = umo.isel(xq=slice(1, None)).load()
# Out:
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/client.py:3363: UserWarning: Sending large graph of size 59.00 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/client.py:3363: UserWarning: Sending large graph of size 59.00 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(

# %%
# open contour data:
isobath_dir = '/g/data/g40/akm157/model_data/mom6/8km_jra_ryf_obc_Charrassin/isobath_1000m_8km_jra_ryf_obc_Charrassin.nc'

data = xr.open_dataset(isobath_dir)
mask_y_transport = data.mask_y_transport
mask_x_transport = data.mask_x_transport
mask_y_transport_numbered = data.mask_y_transport_numbered
mask_x_transport_numbered = data.mask_x_transport_numbered

yh = umo.yh
yq = vmo.yq
xh = vmo.xh
xq = umo.xq

# Convert contour masks to data arrays, so we can multiply them later.
# We need to ensure the lat lon coordinates correspond to the actual data location:
#       The y masks are used for vmo, so like vmo this should have dimensions (yq, xh).
#       The x masks are used for umo, so like umo this should have dimensions (yh, xq).
#       However the actual name will always be simply y or x irrespective of the variable
#       to make concatenation of transports in both direction and sorting possible.
mask_x_transport = xr.DataArray(
    mask_x_transport.values, coords=[('y', yh.data), ('x', xq.data)])
mask_y_transport = xr.DataArray(
    mask_y_transport.values, coords=[('y', yq.data), ('x', xh.data)])
mask_x_transport_numbered = xr.DataArray(
    mask_x_transport_numbered.values, coords=[('y', yh.data), ('x', xq.data)])
mask_y_transport_numbered = xr.DataArray(
    mask_y_transport_numbered.values, coords=[('y', yq.data), ('x', xh.data)])

# number of points along contour:
num_points = int(np.maximum(
    np.max(mask_y_transport_numbered),np.max(mask_x_transport_numbered)))

# stack contour data into 1d:
mask_x_numbered_1d = mask_x_transport_numbered.stack(contour_index = ['y', 'x'])
mask_x_numbered_1d = mask_x_numbered_1d.where(mask_x_numbered_1d > 0, drop = True)
mask_y_numbered_1d = mask_y_transport_numbered.stack(contour_index = ['y', 'x'])
mask_y_numbered_1d = mask_y_numbered_1d.where(mask_y_numbered_1d > 0, drop = True)
contour_ordering = xr.concat((mask_x_numbered_1d,mask_y_numbered_1d), dim = 'contour_index')
contour_ordering = contour_ordering.sortby(contour_ordering)
contour_index_array = np.arange(1, len(contour_ordering)+1)

# %%
rho_0 = 1035.0

# Note that vmo is Ocean Mass Y Transport (kg s-1) and defined as the transport across
# the northern edge of a tracer cell so its coordinates should be (yq, xh).
# umo is Ocean Mass X Transport (kg s-1) and defined as the transport across
# the eastern edge of a tracer cell so its coordinates should be (yh, xq).
# However we will keep the actual name as simply y/x irrespective of the variable
# to make concatenation and sorting possible.
vmo = vmo.rename({'yq':'y', 'xh':'x'})
umo = umo.rename({'yh':'y', 'xq':'x'})

# convert kg/s to Sv and multiply by contour masks
# does not work if do compute here:
vmo = (vmo/(1e6*rho_0)*mask_y_transport)#.compute()
umo = (umo/(1e6*rho_0)*mask_x_transport)#.compute()

# stack transports into 1d and drop any points not on contour:
x_transport_1d = umo.stack(contour_index=['y', 'x'])
x_transport_1d = x_transport_1d.where(mask_x_numbered_1d>0, drop=True)
y_transport_1d = vmo.stack(contour_index=['y', 'x'])
y_transport_1d = y_transport_1d.where(mask_y_numbered_1d>0, drop=True)

# %%
# combine all points on contour:
vol_trans_across_contour = xr.concat((x_transport_1d, y_transport_1d), dim='contour_index')
vol_trans_across_contour = vol_trans_across_contour.sortby(contour_ordering)
vol_trans_across_contour = vol_trans_across_contour.drop_vars({'x', 'contour_index', 'y'})
vol_trans_across_contour.coords['contour_index'] = contour_index_array
vol_trans_across_contour = (vol_trans_across_contour).compute()

# %%
rOM3_DSW_trans = vol_trans_across_contour.copy()

rOM3_DSW_trans.cumsum().plot()

'''save_dir = '/g/data/g40/akm157/model_data/mom6/8km_jra_ryf_obc_Charrassin/cross_slope_transport_yr8_10.nc'
ds = xr.Dataset({'rOM3_DSW_trans': rOM3_DSW_trans})

ds.to_netcdf(save_dir)'''
# Out:
# "save_dir = '/g/data/g40/akm157/model_data/mom6/8km_jra_ryf_obc_Charrassin/cross_slope_transport_yr8_10.nc'\nds = xr.Dataset({'rOM3_DSW_trans': rOM3_DSW_trans})\n\nds.to_netcdf(save_dir)"

# %% [markdown]
# ## Plot together:

# %%
fig, ax1 = plt.subplots()
panan01_DSW_trans.cumsum().plot(ax=ax1,label='panan01',color='C0')
ax1.tick_params(axis='x', top=False, labeltop=False)
ax1.set_ylabel('Cumulative DSW transport (Sv)')
ax1.set_xlabel('Index around Antarctica')

ax2 = ax1.twiny()
panan005_DSW_trans.cumsum().plot(ax=ax2,label='panan005',color='C1')
ax2.tick_params(axis='x', top=False, labeltop=False)
ax2.set_xlabel('')

ax3 = ax1.twiny()
rOM3_DSW_trans.cumsum().plot(ax=ax3,label='rOM3', color= 'C2')
ax3.tick_params(axis='x', top=False, labeltop=False)
ax3.set_xlabel('')

lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
lines3, labels3 = ax3.get_legend_handles_labels()
ax3.legend(lines1 + lines2 + lines3, labels1 + labels2 + labels3, loc=4)

#plt.xticks((0,5,10,15,20))
#plt.xlabel('Year')

plt.title('Transport for rho2 > '+str(density_threshold))
#plt.ylabel('rho2')
#plt.ylim(1037.4,1036.6)
# Out:
# Text(0.5, 1.0, 'Transport for rho2 > 1037.18')
